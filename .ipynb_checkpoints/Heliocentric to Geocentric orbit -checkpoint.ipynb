# %% [markdown]
# # Using Kepler's laws to predict planetary position with an accuracy of ≤1° for ~50   years   from   the   starting   epoch

# %%
import math
import pandas as pd
import numpy as np
from datetime import datetime, timedelta, date, time

# %% [markdown]
# ### Missing planets or celestial bodies

# %% [markdown]
#     *Uranus
#     *Neptune
#     *Pluto
#
#     *Moon
#
#     *Chiron
#     *Ceres
#     *Juno
#     *Lillith
#
# Where can I get the J2000 initial helio longitude for these bodies?

# %% [markdown]
# Values of other planets obtained from this thesis: https://matheo.uliege.be/bitstream/2268.2/4623/1/MasterThesis_ThibaultPicha.pdf

# %% [markdown]
# But if you only want the initial mean longitude and the angular veclocity... the appendix C.1 does have them listed at the beginning... in it, the values are L0 and n for each planet... (The n in the listing is in arcsecond, you have to divide it by 3600 to get your desired degree value.)

# %% [markdown]
#     * Uranus - 314.05500511; 42.231*arcsecond2degree;
#     * Neptune - 304.34866548; 21.534*arcsecond2degree;
#     * Pluto - 238.74394444; 14.3*arcsecond2degree;

# %%
42.231/3600
# Out:
# 0.011730833333333334

# %%
21.534/3600
# Out:
# 0.005981666666666666

# %%
14.3/3600
# Out:
# 0.0039722222222222225

# %%
m_df = {'Planet':['Uranus',"Neptune","Pluto"],'λi':[314.05500511,304.34866548,238.74394444],'T_(Days)':[30687,60190,90560],'ω0':[0.011730833333333334,0.005981666666666666,0.0039722222222222225],'λp':[173.00515922,48.1236905,224.13486111],'e':[0.046295898,0.008988095,0.249050],'a (A.U.)':[19.218446061,30.11038687,39.544674]}

# %%
m_df = pd.DataFrame(data=m_df)
m_df
# Out:
#     Planet          λi  T_(Days)        ω0          λp         e   a (A.U.)
# 0   Uranus  314.055005     30687  0.011731  173.005159  0.046296  19.218446
# 1  Neptune  304.348665     60190  0.005982   48.123691  0.008988  30.110387
# 2    Pluto  238.743944     90560  0.003972  224.134861  0.249050  39.544674

# %% [markdown]
# ### Universal Epoch date in astronomy - J2000 (Julian years)

# %%
# Celestial coordinates at epoch 01.01.2000 @ 00:00 UT
df ={'Planet':['Mercury','Venus','Earth','Mars','Jupiter','Saturn'],'λi':[250.2,181.2,100.0,355.2,34.3,50.1],'T_(Days)':[87.969,224.701,365.256,686.980,4332.59,10759.2],'ω0':[4.09235,1.60213,0.98561,0.52403,0.08309,0.03346],'λp':[77.5,131.6,102.9,336.1,14.3,93.1],'e':[0.2056,0.0068,0.0167,0.0934,0.0485,0.0555], 'a (A.U.)':[0.387,0.723,1.0,1.52,5.2,9.55]}

# %%
df = pd.DataFrame(data=df)

# %%
from IPython.display import Image
Image(filename='img/Screenshot_20200628_174337.png')

# %%
df
# Out:
#     Planet     λi   T_(Days)       ω0     λp       e  a (A.U.)
# 0  Mercury  250.2     87.969  4.09235   77.5  0.2056     0.387
# 1    Venus  181.2    224.701  1.60213  131.6  0.0068     0.723
# 2    Earth  100.0    365.256  0.98561  102.9  0.0167     1.000
# 3     Mars  355.2    686.980  0.52403  336.1  0.0934     1.520
# 4  Jupiter   34.3   4332.590  0.08309   14.3  0.0485     5.200
# 5   Saturn   50.1  10759.200  0.03346   93.1  0.0555     9.550

# %%
from IPython.display import Image
Image(filename='img/Screenshot_20200622_172846.png')

# %% [markdown]
# ### Get days since epoch and user dob

# %%
def get_usr_dob():
    # Enter day, month and year in numerical form (1/4/2020)
    day = int(input("Please enter your day of birth: "))
    month = int(input("Please enter your month of birth: "))
    year = int(input("Please enter your year of birth: "))
    # (1230)
    t = int(input("Please enter your time of birth in HHMM format: "))
    usr_time = time(t)
    usr_dob = date(year, month, day)
    usr_data = datetime.combine(usr_dob, usr_time)
    return usr_data

# %%
# 1 4 2020 0000
usr_data = get_usr_dob()
# Out:
# Please enter your day of birth: 1
# Please enter your month of birth: 1
# Please enter your year of birth: 2007
# Please enter your time of birth in HHMM format: 0000

# %%
def get_yrs_since_epoch(usr_data):
    # Define epoch time
    d = date(2000,1,1)
    t = time(0, 0)
    j2000 = datetime.combine(d,t)
    if j2000 > usr_data:
        yrs_since_epoch = j2000 - usr_data
    else:
        yrs_since_epoch = usr_data - j2000
    return round(yrs_since_epoch.days / 365.25,2)

# %%
get_yrs_since_epoch(usr_data)
# Out:
# 7.0

# %%
def get_days_since_epoch(usr_data):
    # Convert 01.01.2000 @ 00:00 UT to datetime
    d = date(2000,1,1)
    t = time(0, 0)
    j2000 = datetime.combine(d,t)
    # Does the calculation change for dates before j2000? 
    if j2000 > usr_data:
        yrs_since_epoch = j2000 - usr_data
    else:
        yrs_since_epoch = usr_data - j2000
    # convert datetime epoch to int
    days_since_epoch = yrs_since_epoch.days
    return days_since_epoch

# %% [markdown]
# ### Calculate heliocentric longitude

# %%
days_since_epoch = get_days_since_epoch(usr_data)
days_since_epoch
# Out:
# 2557

# %%
years_since_epoch = get_yrs_since_epoch(usr_data)
years_since_epoch
# Out:
# 7.0

# %%
def get_mean_angle_trav(df):
    init_mean_long = df["λi"]
    angle_trav_per_day = df["ω0"]
    mean_ang_traversed = angle_trav_per_day * days_since_epoch
    #print("Mean angle traversed",mean_ang_traversed)
    mean_long = init_mean_long + mean_ang_traversed
    #print("Mean longitude", mean_long)
    helio_mean_long = round(mean_long % 360,2)
    return helio_mean_long

# %%
df['λ0'] = get_mean_angle_trav(df)

# %%
df
# Out:
#     Planet     λi   T_(Days)       ω0     λp       e  a (A.U.)      λ0
# 0  Mercury  250.2     87.969  4.09235   77.5  0.2056     0.387  274.34
# 1    Venus  181.2    224.701  1.60213  131.6  0.0068     0.723  317.85
# 2    Earth  100.0    365.256  0.98561  102.9  0.0167     1.000  100.20
# 3     Mars  355.2    686.980  0.52403  336.1  0.0934     1.520  255.14
# 4  Jupiter   34.3   4332.590  0.08309   14.3  0.0485     5.200  246.76
# 5   Saturn   50.1  10759.200  0.03346   93.1  0.0555     9.550  135.66

# %%
def get_mean_anomoly(df):
    init_mean_long = df["λi"]
    angle_trav_per_day = df["ω0"]
    mean_ang_traversed = angle_trav_per_day * days_since_epoch
    mean_long = init_mean_long + mean_ang_traversed
    helio_mean_long = round(mean_long % 360,2)
    # Convert circular to heliocentric orbit
    perihelion_long = df["λp"]
    eccentricity = df["e"]
    mean_anomaly = round(helio_mean_long - perihelion_long,1)
    return mean_anomaly

# %%
df['θ0(◦) mean anomoly'] = get_mean_anomoly(df)

# %%
df
# Out:
#     Planet     λi   T_(Days)       ω0     λp       e  a (A.U.)      λ0  \
# 0  Mercury  250.2     87.969  4.09235   77.5  0.2056     0.387  274.34
# 1    Venus  181.2    224.701  1.60213  131.6  0.0068     0.723  317.85
# 2    Earth  100.0    365.256  0.98561  102.9  0.0167     1.000  100.20
# 3     Mars  355.2    686.980  0.52403  336.1  0.0934     1.520  255.14
# 4  Jupiter   34.3   4332.590  0.08309   14.3  0.0485     5.200  246.76
# 5   Saturn   50.1  10759.200  0.03346   93.1  0.0555     9.550  135.66
#
#    θ0(◦) mean anomoly
# 0               196.8
# 1               186.3
# 2                -2.7
# 3               -81.0
# 4               232.5
# 5                42.6

# %%
# df['θ0(◦) mean anomoly'] = df.apply(get_mean_anomoly,axis=1)

# %%
def get_delta_anomaly(df):
    Delta_anomaly_1 = round(math.degrees(2*df['e']*(math.sin(math.radians(df['θ0(◦) mean anomoly'])))),1) 
    Delta_anomaly_2 = round(math.degrees(1.25 * df['e']**2*math.sin(math.radians(2*df['θ0(◦) mean anomoly']))),1)
    total_correction = Delta_anomaly_1 + Delta_anomaly_2
    return total_correction

# %%
#df['Total_Delta (◦)'] = get_delta_anomaly(df)
df['Total_Delta (◦)'] = df.apply(get_delta_anomaly,axis=1)

# %%
def get_anomaly(df):
    Anomaly_θ = df['θ0(◦) mean anomoly'] + df['Total_Delta (◦)']
    return Anomaly_θ

# %%
df['Anomaly_θ (◦)'] = df.apply(get_anomaly,axis=1)

# %%
def get_helio_mean_long(df, days_since_epoch):
    'Calculate mean heliocentric longitude (considering each planets orbit to be circular) for a each planet in dataframe for a given date'
    angle_trav_per_day = df["ω0"]
    mean_ang_traversed = angle_trav_per_day * days_since_epoch
    mean_long = df["λi"] + mean_ang_traversed
    helio_mean_long = round(mean_long % 360,2)
    return helio_mean_long

# %%
#df['λ0 Helio'] = df.apply(get_helio_mean_long, args=(days_since_epoch,),axis=1)

# %%
df
# Out:
#     Planet     λi   T_(Days)       ω0     λp       e  a (A.U.)      λ0  \
# 0  Mercury  250.2     87.969  4.09235   77.5  0.2056     0.387  274.34
# 1    Venus  181.2    224.701  1.60213  131.6  0.0068     0.723  317.85
# 2    Earth  100.0    365.256  0.98561  102.9  0.0167     1.000  100.20
# 3     Mars  355.2    686.980  0.52403  336.1  0.0934     1.520  255.14
# 4  Jupiter   34.3   4332.590  0.08309   14.3  0.0485     5.200  246.76
# 5   Saturn   50.1  10759.200  0.03346   93.1  0.0555     9.550  135.66
#
#    θ0(◦) mean anomoly  Total_Delta (◦)  Anomaly_θ (◦)
# 0               196.8             -5.1          191.7
# 1               186.3             -0.1          186.2
# 2                -2.7             -0.1           -2.8
# 3               -81.0            -10.8          -91.8
# 4               232.5             -4.2          228.3
# 5                42.6              4.5           47.1

# %%
def get_helio_final_long(df, days_since_epoch):
    'Calculate heliocentric longitude for a each planet in dataframe for a given date'
    # Convert circular to heliocentric orbit
    frac_of_year = round(days_since_epoch / 365.25,2)
    prec_vern_eqnx = round(frac_of_year * 360/25800,2)
    geo_longitude = df['λ0'] + df['Total_Delta (◦)'] + prec_vern_eqnx
    return geo_longitude

# %%
df['λ Helio'] = df.apply(get_helio_final_long, axis=1, args=(days_since_epoch,))

# %%
# Everything is fine except for Mars mean anomaly for some reason?? 0_o
df
# Out:
#     Planet     λi   T_(Days)       ω0     λp       e  a (A.U.)      λ0  \
# 0  Mercury  250.2     87.969  4.09235   77.5  0.2056     0.387  274.34
# 1    Venus  181.2    224.701  1.60213  131.6  0.0068     0.723  317.85
# 2    Earth  100.0    365.256  0.98561  102.9  0.0167     1.000  100.20
# 3     Mars  355.2    686.980  0.52403  336.1  0.0934     1.520  255.14
# 4  Jupiter   34.3   4332.590  0.08309   14.3  0.0485     5.200  246.76
# 5   Saturn   50.1  10759.200  0.03346   93.1  0.0555     9.550  135.66
#
#    θ0(◦) mean anomoly  Total_Delta (◦)  Anomaly_θ (◦)  λ Helio
# 0               196.8             -5.1          191.7   269.34
# 1               186.3             -0.1          186.2   317.85
# 2                -2.7             -0.1           -2.8   100.20
# 3               -81.0            -10.8          -91.8   244.44
# 4               232.5             -4.2          228.3   242.66
# 5                42.6              4.5           47.1   140.26

# %%
from IPython.display import Image
Image(filename='img/Screenshot_20200622_172846.png')

# %% [markdown]
# ### Convert Heliocentric into Geocentric longitude

# %% [markdown]
# 1. Calculate radii, r, of planet's orbit around the sun, for that epoch, giving their positions in polar form ((r, λ)

# %% [markdown]
# ### r A.U. formula is slightly off, 0.463 for mercury

# %%
def helio_to_geo_long(df):
    r = df['a (A.U.)']*(1-(df['e']**2))/1+(df['e']*(math.cos(df['θ0(◦) mean anomoly'])))
    return r

# %%
df['r(A.U)'] = df.apply(helio_to_geo_long,axis=1)

# %%
# Distance r(A.U) from planet to sun is slightly off, should be 0.463 for Mercury, 0.999 for Earth
df
# Out:
#     Planet     λi   T_(Days)       ω0     λp       e  a (A.U.)  \
# 0  Mercury  250.2     87.969  4.09235   77.5  0.2056     0.387
# 1    Venus  181.2    224.701  1.60213  131.6  0.0068     0.723
# 2    Earth  100.0    365.256  0.98561  102.9  0.0167     1.000
# 3     Mars  355.2    686.980  0.52403  336.1  0.0934     1.520
# 4  Jupiter   34.3   4332.590  0.08308   14.3  0.0485     5.200
# 5   Saturn   50.1  10759.200  0.03346   93.1  0.0555     9.550
#
#    θ0(◦) mean anomoly  Total_Delta (◦)  Anomaly_θ (◦)  λ0 Helio  λ Helio  \
# 0               199.7             -6.0          193.7    277.22   271.50
# 1                19.0              0.3           19.3    150.55   151.13
# 2                86.7              1.9           88.6    189.57   191.75
# 3               -65.2            -10.2          -75.4    270.93   261.01
# 4               274.5             -5.5          269.0    288.76   283.54
# 5               204.5             -2.4          202.1    297.57   295.45
#
#      r(A.U)
# 0  0.413272
# 1  0.729690
# 2  1.004755
# 3  1.439912
# 4  5.169358
# 5  9.467505

# %%
from IPython.display import Image
Image(filename='img/Screenshot_20200622_194743.png')

# %% [markdown]
# ### xH, yH planet coordinates, x0, y0 earth coordinates

# %%
df['Xh'] = df.apply(lambda x: x['r(A.U)'] * math.cos(math.radians(x['λ Helio'])),axis=1)
df['Yh'] = df.apply(lambda x: x['r(A.U)'] * math.sin(math.radians(x['λ Helio'])),axis=1)

# %%
x0 = df.loc[df.Planet == 'Earth', "Xh"].iloc[0]
y0 = df.loc[df.Planet == 'Earth', "Yh"].iloc[0]

# %%
print("x0: ",x0, " y0: ",y0 )
# Out:
# x0:  -0.983700980336424  y0:  -0.20461009816596945

# %%
df['xG'] = df['Xh'] - x0
df['yG'] = df['Yh'] - y0

# %% [markdown]
# ### xG, yG Subtract Earth

# %%
df['rG (A.U.)'] = df.apply(lambda x: math.sqrt((x['xG']**2) + (x['yG']**2)), axis=1)

# %%
df.apply(lambda x: math.sqrt((x['xG']**2) + (x['yG']**2)), axis=1)
# Out:
# 0    1.016144
# 1    0.654965
# 2    0.000000
# 3    1.434644
# 4    5.296817
# 5    9.754437
# dtype: float64

# %%
df2 = df[['Planet','xG','yG']]
df2
# Out:
#     Planet        xG        yG
# 0  Mercury  0.994519 -0.208521
# 1    Venus  0.344699  0.556922
# 2    Earth  0.000000  0.000000
# 3     Mars  0.758697 -1.217613
# 4  Jupiter  2.193973 -4.821074
# 5   Saturn  5.052108 -8.344174

# %%
df2['Inv Tan xG/yG'] = df2.apply(lambda x: math.degrees(math.atan2(x['yG'],x['xG'])),axis=1)
df2
# Out:
# /home/linda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     Planet        xG        yG  Inv Tan xG/yG
# 0  Mercury  0.994519 -0.208521     -11.841659
# 1    Venus  0.344699  0.556922      58.245144
# 2    Earth  0.000000  0.000000       0.000000
# 3     Mars  0.758697 -1.217613     -58.072880
# 4  Jupiter  2.193973 -4.821074     -65.530687
# 5   Saturn  5.052108 -8.344174     -58.806548

# %%
df.columns
# Out:
# Index(['Planet', 'λi', 'T_(Days)', 'ω0', 'λp', 'e', 'a (A.U.)',
#        'θ0(◦) mean anomoly', 'Total_Delta (◦)', 'Anomaly_θ (◦)', 'λ0 Helio',
#        'λ Helio', 'r(A.U)', 'Xh', 'Yh', 'xG', 'yG', 'rG (A.U.)'],
#       dtype='object')

# %%
converter = lambda x: 360+x if x < 0 else (x)

# %%
df2['λg'] = df2['Inv Tan xG/yG'].apply(converter)
# Out:
# /home/linda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#     Planet        xG        yG  Inv Tan xG/yG          λg
# 0  Mercury  0.994519 -0.208521     -11.841659  348.158341
# 1    Venus  0.344699  0.556922      58.245144   58.245144
# 2    Earth  0.000000  0.000000       0.000000    0.000000
# 3     Mars  0.758697 -1.217613     -58.072880  301.927120
# 4  Jupiter  2.193973 -4.821074     -65.530687  294.469313
# 5   Saturn  5.052108 -8.344174     -58.806548  301.193452

# %%
# Testing the accuracy of the angle with planetwatcher Apr 01 2020 12:00 PM
# Mercury
360 - df2['λg'].iloc[0]
# Out:
# 11.8416594473793

# %%
# Mars
360 - df2['λg'].iloc[3]
# Out:
# 58.07287987401634

# %%
# Saturn
360 - df2['λg'].iloc[5]
# Out:
# 58.806547867264555

# %%
print("wow it's fairly accurate")
# Out:
# wow it's fairly accurate

# %% [markdown]
# # Precession of Vernal Equinox, First point of Aries is in Pisces

# %% [markdown]
# ###  For example, on 01/04/2020, geocentric longitude 294.4◦ of Jupiter implies it is in the 10th Zodiac sign Capricorn, but actually lies in the Sagittarius constellation, taking into account the shift by one constellation due to precession.

# %% [markdown]
#     * The 12 constellations are not of equal length of arc along the ecliptic longitude.
#     * There is another constellation, Ophiuchus, through which the ecliptic passes.
#     * For a more precise location of a planet we can calcualte its relative angular distance from the sun along the ecliptic.

# %% [markdown]
# ## Elongation  (ψ) - planet's position with respect to the sun

# %% [markdown]
# * What time did sun rise on a specific day?
# * What is the time difference between UT and inputted location time?
# * What is the elongation between planet and the sun?

# %% [markdown]
# Angle between a planet and the sun with earth as the reference point

# %% [markdown]
# * Longitude increases eastwards
# * If the longitude of the planet is greater than that of the Sun, then the planet lies to the east of the Sun

# %%
from IPython.display import Image
Image(filename='img/Screenshot_20200627_211906.png')

# %% [markdown]
# How to calculate planet's elongation from the sun with geocentric longitude?

# %% [markdown]
# Two other quantities we'd like to know are the phase angle and the elongation.
#
# The phase angle tells us the phase: if it's zero the planet appears "full", if it's 90 degrees it appears "half", and if it's 180 degrees it appears "new". Only the Moon and the inferior planets (i.e. Mercury and Venus) can have phase angles exceeding about 50 degrees.
#
# The elongation is the apparent angular distance of the planet from the Sun. If the elongation is smaller than about 20 degrees, the planet is hard to observe, and if it's smaller than about 10 degrees it's usually not possible to observe the planet.

# %% [markdown]
# ## Find moon's position and moon's nodes

# %% [markdown]
# ## Find positions of planets at any given time

# %% [markdown]
# Is latitude and longitude used in calculating planetary positions in astrology chart or is location used to directly simply convert UT (universal time) to IST (Indian Standard Time) for that day?

# %% [markdown]
# 1. Convert UT time to Time of given location
# 2. Calculate sign that's on the ascendant to plot at 180o on circle

# %% [markdown]
# ## rg, λg are the geocentric values for the Sun’s position.

# %% [markdown]
# The position of Sun on the celestial sphere, as seen from Earth, is in a direction exactly opposite to that of Earth as seen from the Sun. Therefore the geocentric longitude of Sun is the heliocentric longitude of Earth plus 180◦.

# %%
zodiac = ["Pisces", "Aries", "Taurus", "Gemini","Cancer", "Leo", "Virgo", "Libra", "Scorpio", "Sagittarius", "Capricorn", "Aquarius"]

# %%
degrees = []
for i in range(0,361,30):
        degrees.append(i)

# %%
for f, b in zip(zodiac, degrees):
    print(f, b)
# Out:
# Pisces 0
# Aries 30
# Taurus 60
# Gemini 90
# Cancer 120
# Leo 150
# Virgo 180
# Libra 210
# Scorpio 240
# Sagittarius 270
# Capricorn 300
# Aquarius 330

# %% [markdown]
# ## Relative angular distance

# %% [markdown]
# For a more precise location of a planetwe can calculate its relative angular distance from the Sun along the ecliptic.

# %%
345.3 + 11.8
# Out:
# 357.1

# %% [markdown]
# ### What is right ascension, declination?

# %% [markdown]
# ### How to find positions of other planets for J2000

# %% [markdown]
# ### Sunrise and sunset times

# %% [markdown]
# ## Plot planet position on circle

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### How to account for the fact that 0 degrees on natal astrology chart needs to start at 180 degrees on standard chart

# %%
import random
import math
import matplotlib.pyplot as plt


def circle():
    x = []
    y = []
    for i in df2['λg']:
        print(i)
        x.append(math.cos(i));
        y.append(math.sin(i));
    plt.axes().set_aspect('equal', 'datalim')  # before `plt.show()`
    plt.scatter(x,y)
    plt.show()
circle()
# Out:
# 348.1583405526207
# 58.245144493710185
# 0.0
# 301.92712012598366
# 294.4693125417341
# 301.19345213273544

# %%
def circle():
    plt.figure(figsize=(20,10))
    x = []
    y = []
    for i in df2['λg']:
        print(i)
        x.append(math.cos(i));
        y.append(math.sin(i));
#     plt.plot(np.linspace(0, 2*np.pi, 100), np.ones(100)*5, color='r', linestyle='-')
    plt.subplot(111, projection='polar')
#     plt.axes().set_aspect('equal', 'datalim')  # before `plt.show()`
    plt.plot(x,y)
    plt.show()
circle()
# Out:
# 348.1583405526207
# 58.245144493710185
# 0.0
# 301.92712012598366
# 294.4693125417341
# 301.19345213273544
# /home/linda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # Remove the CWD from sys.path while we load stuff.

# %%
import numpy as np
import matplotlib.pyplot as plt


plt.figure(figsize=(20,10))

r = np.arange(356,300,56,60,321)
theta = 2 * np.pi * r
# Compute pie slices

ax = plt.subplot(111, projection='polar') # lambert
ax.plot(theta, r)

# bars = ax.bar(theta, radii, width=width, bottom=0.0)

# Use custom colors and opacity
# for r, bar in zip(radii, bars):
#     bar.set_facecolor(plt.cm.viridis(r / 10.))
#     bar.set_alpha(0.5)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-175-cd58ffaa7643> in <module>
#       5 plt.figure(figsize=(20,10))
#       6
# ----> 7 r = np.arange(356,300,56,60,321)
#       8 theta = 2 * np.pi * r
#       9 # Compute pie slices
#
# TypeError: arange() takes at most 4 arguments (5 given)

# %%
r = np.arange(0, 2, 0.01)

# %%
df2.columns
# Out:
# Index(['Planet', 'xG', 'yG', 'Inv Tan xG/yG', 'λg'], dtype='object')

# %%
r = df2['λg'].array
r
# Out:
# <PandasArray>
# [ 348.1583405526207, 58.245144493710185,                0.0,
#  301.92712012598366,  294.4693125417341, 301.19345213273544]
# Length: 6, dtype: float64

# %%
import turtle
window = turtle.Screen()
turtle.bgcolor("yellow")
window.exitonclick()

# %% [markdown]
# ## Start react native app
