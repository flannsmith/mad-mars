# %% [markdown]
# ## Steps I need to take:
# 1. How to find Earth latitude and longitude based on location input
# 2. How does latitude and longitude on Earth affect position of planets in sky e.g. to denote rising sign of chart
# 3. How to delineate which astro constellation each planet is in based on lat and long.
# 4. How to interpolate planetary positions to 360 chart
# 5. Understand and identify planetary retrograde cycles
# 6. Calculate and understand lunar nodes

# %% [markdown]
# ### Calculate planetary position

# %% [markdown]
# https://arxiv.org/pdf/0910.2778.pdf

# %% [markdown]
# * Need initial planetary orbit specifications for some standard epoch
# * their time periods of revolution

# %% [markdown]
# Initially consider the planets to revolve around the Sun in uniform circular motions.
# Knowing their original positions for the starting epoch, we calculate their approximate positions for the intended epoch.
# Since planetary orbits are elliptical there will be some errors in approximation as in an elliptical orbit the angular speed of the planet is not uniform and to an extent varies.

# %% [markdown]
# ### Ecliptic

# %% [markdown]
# Is the sun's path around the celestial sphere. The zodiac constellations are just 12 divisions of the ecliptic into 12 parts.

# %% [markdown]
# ### Epoch

# %% [markdown]
# Is a moment in time for which celestial co-ordinates or orbital elements are specified, while a celestial co-ordinate system is a co-ordinate system for mapping positions in the sky.

# %% [markdown]
# The ecliptic co-ordinate system uses the ecliptic for its fundamental plane.
# The longitudi-nal angle is called the ecliptic longitude orcelestial longitude (denoted by λ), measured eastwards from 0◦to 360◦from the vernal equinox.

# %% [markdown]
# The Earth’s axis of rotation precessesaround the ecliptic axis with a time pe-riod of about 25800 years

# %% [markdown]
# Most planets, dwarf planets, and manysmall solar system bodies have orbits withsmall inclinations to the ecliptic plane, andtherefore their ecliptic latitudeβis alwayssmall. Due of only small deviations of theorbital planes of the planets from the planeof the ecliptic, the ecliptic longitude alonemay suffice to locate planets in the sky.

# %% [markdown]
# ### Heliocentric circular orbit

# %% [markdown]
# The initial values of mean longitudes (λi) of the planets given in Table 1 are for 1st of January, 2000 A.D., 00:00 UT (adapted from [2]).
#
# Period T (days) of revolution of the planets.
#
# Mean angular speed ω0=360/T(◦/day)
#
# Mean Longitude of the planets in the imaginary circular orbit for subsequent dates as λ0
#
# ### How to calculate mean longitude λ0 for Mars on April 1, 2020
#
# We now demonstrate how to calculate λ0 for Mars on April 1, 2020.
#
#     *The initial mean longitude, λi, of Mars on 01.01.2000 at 00:00 UT = 355.2◦.
#     *Number of days between 01.01.2000 and 01.04.2020 = 7396.
#     *Mean angle traversed duration this pe-riod=0.52403×7396=3, 875.7◦.
#     *So, on 01.04.2020 at 00:00 UT, the mean longitudes is λ0,=355.2+3, 875.7=4,230.9=360×11+270.9◦.

# %% [markdown]
# ### Heliocentric elliptical orbit
# Next, need to correct for eccentricity of certain planets (elliptical orbit). In a circular motion, the angular speed of the planetis constant, however, in an elliptical orbit, the angular speed of the planet varies with time.
#
# Before we could make corrections forthe elliptical shape of the orbit we need toknow the orientation of the ellipse withinthe ecliptic and that can be defined by thelongitude (λp) of the perihelion.
#
# Before we could make corrections forthe elliptical shape of the orbit we need toknow the orientation of the ellipse withinthe ecliptic and that can be defined by thelongitude (λp) of the perihelion.
#
# Before we could make corrections forthe elliptical shape of the orbit we need toknow the orientation of the ellipse withinthe ecliptic and that can be defined by thelongitude (λp) of the perihelion.  The dis-tance of the planet from Sun varies in anelliptical orbit and perihelion is the pointon the elliptical orbit that lies closest toSun (the orbital point farthest from Sun iscalled aphelion).  Longitudinal distance ofthe planet from the perihelion along the el-liptical orbit is known as its “anomaly” (de-noted by θ), while angular distance of meanposition of planet with respect to the perihe-lion is called the “mean anomaly” (denotedby θ0).
#
# ∆θ=2esinθ0+5/4 e2sin 2θ0,

# %% [markdown]
# In Table 2, we have listed values of thelongitude of perihelion (λp) and eccentricity(e) for all planets, taken from [2].Let’s consider Mercury’s position on 01/04/20 at 00:00 UT.

# %%
mean_longitude = 277.2
perihelion_long = 77.5

# %% [markdown]
# ### Need to get geocentric ecliptic longitude

# %% [markdown]
# If you already have a geocentric ecliptic longitude, most likely no further correction is required. When the ephemeris calculator computes each planet's heliocentric position (including Earth), it accounts for eccentricity by converting mean anomaly to true anomaly.

# %% [markdown]
# ### How to calculate geocentric ecliptic longitude

# %% [markdown]
# http://farside.ph.utexas.edu/Books/Syntaxis/Almagest/node34.html

# %% [markdown]
# ### How to calculate which sign or constellation planet is in based on geocentric ecliptic longitude

# %% [markdown]
# ### How to calculate if a planet is in retrograde

# %% [markdown]
# https://astronomy.stackexchange.com/questions/18832/mathematically-calculate-if-a-planet-is-in-retrograde

# %% [markdown]
# ### Astrology chart is geocentric - planets observed from perspective of Earth (Earth-centered)

# %% [markdown]
# What is declination?
#
# The angular distance of a point north or south of the celestial equator.
#
# ![image.png](attachment:image.png)

# %%
# !pip install solarsystem
# Out:
# ...
#   Created wheel for solarsystem: filename=solarsystem-0.1.5-cp37-none-any.whl size=16632 sha256=2220f84e263a936b2f8a0e05c887ad2aef91cfb38121f8990e2f6df429141b2d
#   Stored in directory: /home/linda/.cache/pip/wheels/c3/4c/9b/832a569b6acd07b0daf77a6084a1815496b04b2a84be65ec84
# Successfully built solarsystem
# ...

# %%
import matplotlib.pyplot as plt
import datetime
import solarsystem

# %%
now    = datetime.datetime.utcnow()
now    = datetime.datetime.now(datetime.timezone.utc)
year   = now.year
month  = now.month
day    = now.day
hour   = now.hour
minute = now.minute
# As this is UTC time we set UT to 0
UT     = 0
# if (datetime.datetime.now(datetime.timezone.utc).dst())==None:
#     dst=0
# else:
#     dst=1
dst = 0

print(year, month, day, hour, minute, UT, dst)
# Out:
# 2020 6 11 13 13 0 0

# %%
# planet position output be in horizontal coordinates (longitude, latitude, distance from sun in AU)
view='horizontal'

# %%
H = solarsystem.Heliocentric(year=year, month=month, day=day, hour=hour, minute=minute, 
                         UT=UT, dst=dst, view=view )

# %%
planets=H.planets()
distances=[]
print('Planet', '   \t','Longitude', '  \t','Latitude', '   \t','Distance')
print('-------------------------------------------------------------------')
for key in planets:
    distances.append(planets[key][2])
    elements = planets[key]
    print(key, '   \t',round(elements[0],2), '  \t',round(elements[1],2), '   \t',round(elements[2],2))
print()
print('Distance is in AU')
# Out:
# Planet    	 Longitude   	 Latitude    	 Distance
# -------------------------------------------------------------------
# Mercury    	 224.91   	 0.45    	 0.45
# Venus    	 266.0   	 -0.54    	 0.73
# Earth    	 261.08   	 0.0    	 1.02
# Mars    	 303.16   	 -1.77    	 1.4
# Jupiter    	 289.58   	 359.8    	 5.17
# Saturn    	 297.43   	 359.84    	 10.03
# Uranus    	 37.14   	 359.53    	 19.79
# Neptune    	 349.0   	 -1.06    	 29.91
# Pluto    	 293.56   	 359.08    	 33.98
# Ceres    	 321.17   	 -9.25    	 2.98
# Chiron    	 5.86   	 2.77    	 18.83
# Eris    	 23.64   	 -11.66    	 95.96
#
# Distance is in AU

# %% [markdown]
# The astronomical unit is a unit of length, roughly the distance from Earth to the Sun and equal to about 150 million kilometres. However, that distance varies as Earth orbits the Sun, from a maximum to a minimum and back again once a year.

# %%
Hr = solarsystem.Heliocentric(year=year, month=month, day=day, hour=hour, minute=minute, 
                         UT=UT, dst=dst, view='rectangular' )
planetspositionsHrect=Hr.planets()
planetspositionsHrect
# Out:
# {'Mercury': (-0.31734741625024276, -0.3163491632534753, 0.003518539961106384),
#  'Venus': (-0.05073362202405862, -0.7249153161089941, -0.0068419447216946615),
#  'Earth': (-0.15750624407951622, -1.0031300873905182, 0),
#  'Mars': (0.7659794630493734, -1.1722051066714698, -0.04334440005453868),
#  'Jupiter': (1.7325533289248112, -4.869829168692515, -0.018169648363688732),
#  'Saturn': (4.62205538449811, -8.90558492301331, -0.02824039605153665),
#  'Uranus': (15.774263583851932, 11.946103522604647, -0.16059537237284544),
#  'Neptune': (29.356859559394486, -5.705354205950137, -0.555525496526587),
#  'Pluto': (13.582547345831122, -31.146461583007174, -0.5450233627141755),
#  'Ceres': (2.290734922783648, -1.8435989610248327, -0.47909032690955833),
#  'Chiron': (18.710453921317367, 1.9204814981086091, 0.9113362714879744),
#  'Eris': (86.09427484126311, 37.69369170019999, -19.39010117972836)}

# %%
forplot=[]
planetname=[]
for key in planetspositionsHrect:
    planetname.append(key)
    forplot.append(   planetspositionsHrect[key] )

# %%
forplot
# Out:
# [(-0.31734741625024276, -0.3163491632534753, 0.003518539961106384),
#  (-0.05073362202405862, -0.7249153161089941, -0.0068419447216946615),
#  (-0.15750624407951622, -1.0031300873905182, 0),
#  (0.7659794630493734, -1.1722051066714698, -0.04334440005453868),
#  (1.7325533289248112, -4.869829168692515, -0.018169648363688732),
#  (4.62205538449811, -8.90558492301331, -0.02824039605153665),
#  (15.774263583851932, 11.946103522604647, -0.16059537237284544),
#  (29.356859559394486, -5.705354205950137, -0.555525496526587),
#  (13.582547345831122, -31.146461583007174, -0.5450233627141755),
#  (2.290734922783648, -1.8435989610248327, -0.47909032690955833),
#  (18.710453921317367, 1.9204814981086091, 0.9113362714879744),
#  (86.09427484126311, 37.69369170019999, -19.39010117972836)]

# %%
plt.figure(figsize=(15,15))
ax = plt.gca()
ax.cla() 
ax.set_xlim((-33, 33))
ax.set_ylim((-33, 33))
a=0.5
ax.plot(0,0,'.', label='Sun') 
for i in range(11):
    ax.plot(forplot[i][0] , forplot[i][1] ,'.', markersize=10, label=planetname[i]) 
    if (i >1) & (i < 10):
        ax.add_artist(plt.Circle((0, 0), ((abs(forplot[i][0])**2+abs(forplot[i][1])**2)**0.5), color='r', fill=False))
ax.legend()
plt.show()
